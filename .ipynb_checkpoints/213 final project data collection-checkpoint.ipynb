# %% [markdown]
# # Dependencies

# %%
import pandas as pd, csv, os
#import numpy as np, census, us, math Not currently needed
import requests, json
import urllib2
import re
from scipy.stats import norm # needed for percent point function norm.ppf (used in significance testing)

# %% [markdown]
# # Global Variables

# %%
apikey = "827a8aafba255606ced9b44cd4380ba61ad39003" # Drew's API key, stay cool bros

# %%
ttracts = ["06075980900","06075061400","06075061200","06075023003","06075061000",
           "06075060700","06075026403","06075026401","06075026402","06075025800",
           "06075023400","06075023300","06075023200","06075023102","06075022702",
           "06075022600"]

sf = ["0667000"] # State 06 (CA), place 67000 (San Francisco city)

# %% [markdown]
# # Helper Functions

# %%
def chunks(l, n):
    """Returns a list of lists no longer than n (used to deal with Census API limit of 50 variables per call)"""
    if n < 1:
        n = 1
    return [l[i:i + n] for i in range(0, len(l), n)]

# %%
def concatenate_dataframes(geo_type, *dfs):
    """Stitches together multiple dataframes. Drops state, county, tract, place from dfs as they are already encoded in index"""
    if geo_type == "tract":
        masterframe = dfs[0].iloc[:,:-3]
    elif geo_type == "place":
        masterframe = dfs[0].iloc[:,:-2]

    if len(dfs) > 1:
        for df in dfs[1:]:
            masterframe = pd.concat([masterframe, df.iloc[:,:-3 if geo_type == "tract" else -2]], axis = 1) 
            # axis="1": concat across col instead of across rows
            
    return masterframe

# %%
def se_rename(text):
    """Replaces "Margin of Error" with "Standard Error" in column names"""
    try:
        strings = re.search('(^.+ )Margin .f Error(.+$)', text)
    except AttributeError:
        strings = '' # apply your error handling

    return strings.group(1) + "Standard Error" + strings.group(2)

# %%
# Homemade Census API calling, more flexible than the census package permits
# HUGE thanks to Aksel Olsen (via Sam Blanchard) for this function

def get_data(year,dataset,table,geo_type):
    """
    Gets data from api based on year, dataset and tablename
    """
    
    #concatenate table list to pass to url param
    stable = ','.join(table)
    
    url = 'http://api.census.gov/data/%(yr)s/%(dset)s?key=%(key)s&get=%(tbl)s&for=%(type)s:*&in=state:06'
    url = url %{
    'key':apikey,
    'yr':year,
    'dset':dataset,
    'tbl':stable,
    'type': geo_type
    }
#    print url
    ## get data
    resp = requests.get(url)
        
    try:
#        print year, dataset, stable, geo_type
        data = pd.read_json(resp.text)
        
        ## col names are found at index 0
        cols = data.ix[0,].tolist()
           
        data.columns=cols
                        
        ## data ships with empty row--remove, or else it won't work (DSL 10/12/2014)
        data=data.drop(data.index[:1])
        
        if year == "2000": # Dealing with the lack of leading zeros in 2000 FIPS codes cost me well over an hour. :(
            data["state"] = data["state"].apply("{:0>2}".format)
            if geo_type == "tract":
                data["county"] = data["county"].apply("{:0>3}".format)
                data["tract"] = data["tract"].apply("{:0>6}".format)
            else:
                data["place"] = data["place"].apply("{:0>5}".format)

        # Leaving in all this debris from my long struggle with this problem. FYI the correct answer is here: http://stackoverflow.com/questions/23836277/add-leading-zeros-to-strings-in-pandas-dataframe
#        print data.head()
#        if year == "2000":
#            data.state = data.state.astype(str)
#            total_rows['ColumnID'] = total_rows['ColumnID'].astype(str)
#            data["state"] = str(data["state"]).zfill(2)
#        print data.head()
        ## add unique geoid as index - using ternary operator to select correct geoid format AND using zfill to ensure proper formatting of 2000 data (which normally lack leading zeros)
        data.index = data.state + data.county + data.tract if geo_type == "tract" else data.state + data.place
#        data.index = "%02d%03d%06d" % (data.state, data.county, data.tract) if geo_type == "tract" else "%02d%05d" % (data.state, data.place)
#        data.index = "%02s%03s%06s" % (data.state, data.county, data.tract) if geo_type == "tract" else "%02s%05s" % (data.state, data.place)
#        data.index = str(data.state).zfill(2)+str(data.county).zfill(3)+str(data.tract).zfill(6) if geo_type == "tract" else str(data.state).zfill(2)+str(data.place).zfill(5)
                
        ## make sure numeric data is numeric
        data.ix[:,table]=data[table].astype('float64')
        
        return data
    except Exception, e:
        raise    # decoding failed
        print "holy smokes!"
        print "failed on %s" %url
    else:
        pass

# %%
def census_api_pull(vars_list, year, dataset, geo_type):
    """Takes an arbitrarily long list of variables, a year and dataset (e.g. "sf1", "acs5"), makes multiple API calls and stitches it all together"""
    ## get variable details, labels
    jsonurl = 'http://api.census.gov/data/%(yr)s/%(dset)s/variables.json' % {'yr': year, 'dset': dataset}
    jsontext = requests.get(jsonurl)

    ## rename columns, looking up in dictionary. Perhaps bad form w verbose names
    datadict = pd.DataFrame(jsontext.json()['variables']).T
        
    ## get labels, stuff in dict
    datadict_rename = datadict.ix[vars_list,'label'].to_dict()
    datadict_rename_verbose = dict(zip(datadict_rename.keys(), [str(key) + " " + str(value) for key, value in datadict_rename.items()]))
        
    var_chunks = chunks(vars_list, 50) # split up the LIST into chunks of 50 variables
    results_list = []
    
    for var_chunk in var_chunks:
        df = get_data(year, dataset, var_chunk, geo_type) # perform census api pull (using Aksel's code)
        results_list.append(df) #append the df to results_list
        
    masterframe = concatenate_dataframes(geo_type, *results_list) #I think the splat is needed here

    ## rename: new name has both official variable name and legible description
    masterframe.rename(columns=datadict_rename_verbose,inplace=True)
    
    fname = "%s_%s_%s.csv" % (dataset, year, geo_type)
    print "writing data to %s" % fname
    masterframe.to_csv(fname)
    
    return masterframe

# %%
def get_dataframes(vardict):
    """Generates a dictionary of dataframes for various Census API pulls (year, dataset, place/tract)"""
    dataframes = {}
    
    for column in vardict:
        if column != "Topic" and column != "Name":
            dataframes[column + "_tract"] = census_api_pull(vardict[column].dropna(), re.search("_(.+)$", column).group(1), re.search("^(.+)_", column).group(1), "tract")
            dataframes[column + "_place"] = census_api_pull(vardict[column].dropna(), re.search("_(.+)$", column).group(1), re.search("^(.+)_", column).group(1), "place")
    
    return dataframes

# %%
def filter_dfs(dfdict, tract_filter, place_filter):
    """Returns a dict of dataframes filtered by tract and place FIPS lists"""
    newdict = {}
    
    for key in dfdict:
        if "tract" in key:
            newdict[key] = dfdict[key][dfdict[key].index.isin(tract_filter)]
        elif "place" in key:
            newdict[key] = dfdict[key][dfdict[key].index.isin(place_filter)]
    
    return newdict

# %%
def agg_filtered_dfs(dfdict):
    newdict = {}
    
    for key in dfdict:
        newdict[key] = agg(dfdict[key])
    
    return newdict

# %%
def master_pull(vardict, tract_filter, place_filter):
    dfs = get_dataframes(vardict) # Get the dataframes into a dictionary
    print "Retrieved data - saved to CSVs"
    
    dfs_filter = filter_dfs(dfs, tract_filter, place_filter) # Filter to desired geographies
    print "Filtered tracts and places"
    
    dfs_filter.update((x, moe_to_se(y)) for x, y in dfs_filter.items()) # Convert MOE to SE
    print "Converted MOE to SE"
    
    dfs_filter_agg = agg_filtered_dfs(dfs_filter) # Aggregate estimates and SEs
    print "Aggregated estimates and SEs"
    
    return dfs_filter_agg

# %% [markdown]
# # Analysis Functions

# %%
def significant(x, x_se, y, y_se, ci):
    """Returns True if the difference between x and y, given x_se and y_se, is statistically significant at the given confidence interval"""
    p = ci + (1 - ci)/2 # convert confidence interval into two-tailed test critical value
    z = norm.ppf(p) # z-score
    return abs((x - y)/(x_se**2 + y_se**2)**0.5) > z

# %%
def moe_to_se(df):
    """Converts all Margin Of Error columns into Standard Error (by dividing by 1.645), and renames columns accordingly"""
    colnames = []
    new = df.copy()
    
    for colname in new.columns:
        if "margin of error" in colname.lower():
            new[colname] = new[colname] / 1.645
            colnames.append(se_rename(colname))
        else:
            colnames.append(colname)
    
    new.columns = colnames
    
    return new

# %%
def proportion_moe(num, num_moe, den, den_moe):
    """Calculates MOE for a proportion (use after aggregating estimates and MOEs across multiple tracts)"""
    p = float(num) / den

    if num_moe**2 - (p**2 * den_moe**2) >= 0:
        return (num_moe**2 - (p**2 * den_moe**2))**0.5 / den
    else:
        return (num_moe**2 + (p**2 * den_moe**2))**0.5 / den

# %%
def agg(df):
    """Aggregate census tracts for tables with counts"""
    new = df.copy()
    new.loc['Aggregate'] = 0
    for i in new.columns:
        if "Margin Of Error" in i or "Standard Error" in i:
            new.loc["Aggregate", i] = (sum(new[i]**2))**.5
        else:
            new.loc["Aggregate", i] = sum(new[i])
    return new.loc["Aggregate"]

# %% [markdown]
# # Test Code

# %%
# Just for future reference, this is basically how this will work

#proportion_moe(aggregate.filter(regex = "B01001_002E")[0], 
#               aggregate.filter(regex = "B01001_002M")[0], 
#               aggregate.filter(regex = "B01001_001E")[0], 
#               aggregate.filter(regex = "B01001_001M")[0])

# %%
import sys

if __name__ == "__main__":
    reload(sys)
    sys.setdefaultencoding("utf-8")
    
# Apparently I have to do this to handle a UnicodeError that the next snippet would throw?
# But now print statements don't output to the console...
# Whatever, as long as I get my data correctly

# %%
### LET'S DO THIS!!!!! ###

vardict = pd.read_csv("vardict.csv")

results = master_pull(vardict, village, richmond)

acs5_2012 = pd.concat([results["acs5_2012_place"], results["acs5_2012_tract"]], axis = 1)
acs5_2012.columns = ["Richmond", "Village"]
print "writing data to acs5_2012.csv"
acs5_2012.to_csv("acs5_2012.csv")

sf1_2010 = pd.concat([results["sf1_2010_place"], results["sf1_2010_tract"]], axis = 1)
sf1_2010.columns = ["Richmond", "Village"]
print "writing data to sf1_2010.csv"
sf1_2010.to_csv("sf1_2010.csv")

sf1_2000 = pd.concat([results["sf1_2000_place"], results["sf1_2000_tract"]], axis = 1)
sf1_2000.columns = ["Richmond", "Village"]
print "writing data to sf1_2000.csv"
sf1_2000.to_csv("sf1_2000.csv")

sf3_2000 = pd.concat([results["sf3_2000_place"], results["sf3_2000_tract"]], axis = 1)
sf3_2000.columns = ["Richmond", "Village"]
print "writing data to sf3_2000.csv"
sf3_2000.to_csv("sf3_2000.csv")

# %%
### Smaller version of LET'S DO THIS!!!!! that pulls everything but ACS5, for speed reasons

vardict = pd.read_csv("vardict.csv")

results = master_pull(vardict.iloc[:, 3:], elmhurst, oakland)

sf1_2010 = pd.concat([results["sf1_2010_place"], results["sf1_2010_tract"]], axis = 1)
sf1_2010.columns = ["Oakland", "Elmhurst"]
print "writing data to sf1_2010.csv"
sf1_2010.to_csv("sf1_2010.csv")

sf1_2000 = pd.concat([results["sf1_2000_place"], results["sf1_2000_tract"]], axis = 1)
sf1_2000.columns = ["Oakland", "Elmhurst"]
print "writing data to sf1_2000.csv"
sf1_2000.to_csv("sf1_2000.csv")

sf3_2000 = pd.concat([results["sf3_2000_place"], results["sf3_2000_tract"]], axis = 1)
sf3_2000.columns = ["Oakland", "Elmhurst"]
print "writing data to sf3_2000.csv"
sf3_2000.to_csv("sf3_2000.csv")

# %%
### LET'S DO THIS!!!!! ###

vardict = pd.read_csv("vardict.csv")

results = master_pull(vardict.iloc[:, 2:], elmhurst, oakland)

sf1_2010 = pd.concat([results["sf1_2010_place"], results["sf1_2010_tract"]], axis = 1)
sf1_2010.columns = ["Oakland", "Elmhurst"]
print "writing data to sf1_2010.csv"
sf1_2010.to_csv("sf1_2010.csv")

sf1_2000 = pd.concat([results["sf1_2000_place"], results["sf1_2000_tract"]], axis = 1)
sf1_2000.columns = ["Oakland", "Elmhurst"]
print "writing data to sf1_2000.csv"
sf1_2000.to_csv("sf1_2000.csv")
# Out:
# writing data to sf1_2010_tract.csv
# writing data to sf1_2010_place.csv
# writing data to sf1_2000_tract.csv
# writing data to sf1_2000_place.csv
# Retrieved data - saved to CSVs
# Filtered tracts and places
# Converted MOE to SE
# Aggregated estimates and SEs
# writing data to sf1_2010.csv
# writing data to sf1_2000.csv

# %% [markdown]
# #### For Projections assignment

# %%
vars1990 = ["P0120001","P0120002","P0120003","P0120004","P0120005","P0120006","P0120007","P0120008","P0120009","P0120010","P0120011","P0120012","P0120013","P0120014","P0120015","P0120016","P0120017","P0120018","P0120019","P0120020","P0120021","P0120022","P0120023","P0120024","P0120025","P0120026","P0120027","P0120028","P0120029","P0120030","P0120031","P0120032","P0120033","P0120034","P0120035","P0120036","P0120037","P0120038","P0120039","P0120040","P0120041","P0120042","P0120043","P0120044","P0120045","P0120046","P0120047","P0120048","P0120049","P0120050","P0120051","P0120052","P0120053","P0120054","P0120055","P0120056","P0120057","P0120058","P0120059","P0120060","P0120061","P0120062","P0120063","P0120064","P0120065","P0120066","P0120067","P0120068","P0120069","P0120070","P0120071","P0120072","P0120073","P0120074","P0120075","P0120076","P0120077","P0120078","P0120079","P0120080","P0120081","P0120082","P0120083","P0120084","P0120085","P0120086","P0120087","P0120088","P0120089","P0120090","P0120091","P0120092","P0120093","P0120094","P0120095","P0120096","P0120097","P0120098","P0120099","P0120100","P0120101","P0120102","P0120103","P0120104","P0120105","P0120106","P0120107","P0120108","P0120109","P0120110","P0120111","P0120112","P0120113","P0120114","P0120115","P0120116","P0120117","P0120118","P0120119","P0120120","P0120121","P0120122","P0120123","P0120124","P0120125","P0120126","P0120127","P0120128","P0120129","P0120130","P0120131","P0120132","P0120133","P0120134","P0120135","P0120136","P0120137","P0120138","P0120139","P0120140","P0120141","P0120142","P0120143","P0120144","P0120145","P0120146","P0120147","P0120148","P0120149","P0120150","P0120151","P0120152","P0120153","P0120154","P0120155","P0120156","P0120157","P0120158","P0120159","P0120160","P0120161","P0120162","P0120163","P0120164","P0120165","P0120166","P0120167","P0120168","P0120169","P0120170","P0120171","P0120172","P0120173","P0120174","P0120175","P0120176","P0120177","P0120178","P0120179","P0120180","P0120181","P0120182","P0120183","P0120184","P0120185","P0120186","P0120187","P0120188","P0120189","P0120190","P0120191","P0120192","P0120193","P0120194","P0120195","P0120196","P0120197","P0120198","P0120199","P0120200","P0120201","P0120202","P0120203","P0120204","P0120205","P0120206","P0120207","P0120208","P0120209","P0120210","P0120211","P0120212","P0120213","P0120214","P0120215","P0120216","P0120217","P0120218","P0120219","P0120220","P0120221","P0120222","P0120223","P0120224","P0120225","P0120226","P0120227","P0120228","P0120229","P0120230","P0120231","P0120232","P0120233","P0120234","P0120235","P0120236","P0120237","P0120238","P0120239","P0120240","P0120241","P0120242","P0120243","P0120244","P0120245","P0120246","P0120247","P0120248","P0120249","P0120250","P0120251","P0120252","P0120253","P0120254","P0120255","P0120256","P0120257","P0120258","P0120259","P0120260","P0120261","P0120262","P0120263","P0120264","P0120265","P0120266","P0120267","P0120268","P0120269","P0120270","P0120271","P0120272","P0120273","P0120274","P0120275","P0120276","P0120277","P0120278","P0120279","P0120280","P0120281","P0120282","P0120283","P0120284","P0120285","P0120286","P0120287","P0120288","P0120289","P0120290","P0120291","P0120292","P0120293","P0120294","P0120295","P0120296","P0120297","P0120298","P0120299","P0120300","P0120301","P0120302","P0120303","P0120304","P0120305","P0120306","P0120307","P0120308","P0120309","P0120310"]

# census_api_pull(vars_list, year, dataset, geo_type):
sexage1990 = census_api_pull(vars1990, 1990, "sf1", "tract")

sexage1990.head()
# Out:
# writing data to sf1_1990_tract.csv
#          P0120001 White Males '<' 1 yr P0120002 White Males 1-2 yrs  \
# 60014001                             7                           21
# 60014002                            14                           21
# 60014003                            18                           40
# 60014004                            13                           31
# 60014005                             4                           13
#
#          P0120003 White Males 3-4 yrs P0120004 White Males 5 yrs  \
# 60014001                           12                          6
# 60014002                           16                          6
# 60014003                           38                         20
# 60014004                           24                          8
# 60014005                            4                          4
#
#          P0120005 White Males 6 yrs P0120006 White Males 7-9 yrs  \
# 60014001                          7                           30
# 60014002                          6                           16
# 60014003                         14                           45
# 60014004                          5                           29
# 60014005                          4                            9
#
#          P0120007 White Males 10-11 yrs P0120008 White Males 12-13 yrs  \
# 60014001                             14                             12
# 60014002                             14                             22
# 60014003                             20                             19
# 60014004                             15                              8
# 60014005                              8                              3
#
#          P0120009 White Males 14 yrs P0120010 White Males 15 yrs  \
# 60014001                           7                           8
# 60014002                           5                           7
# 60014003                           8                           5
# 60014004                           3                           4
# 60014005                           3                           2
#
#                      ...             P0120301 Other Race Females 45-49 yrs  \
# 60014001             ...                                                 1
# 60014002             ...                                                 2
# 60014003             ...                                                 2
# 60014004             ...                                                 0
# 60014005             ...                                                 2
#
#          P0120302 Other Race Females 50-54 yrs  \
# 60014001                                     0
# 60014002                                     1
# 60014003                                     1
# 60014004                                     2
# 60014005                                     0
#
#          P0120303 Other Race Females 55-59 yrs  \
# 60014001                                     0
# 60014002                                     0
# 60014003                                     1
# 60014004                                     2
# 60014005                                     1
#
#          P0120304 Other Race Females 60-61 yrs  \
# 60014001                                     0
# 60014002                                     0
# 60014003                                     1
# 60014004                                     0
# 60014005                                     0
#
#          P0120305 Other Race Females 62-64 yrs  \
# 60014001                                     0
# 60014002                                     0
# 60014003                                     0
# 60014004                                     0
# 60014005                                     1
#
#          P0120306 Other Race Females 65-69 yrs  \
# 60014001                                     0
# 60014002                                     0
# 60014003                                     1
# 60014004                                     2
# 60014005                                     1
#
#          P0120307 Other Race Females 70-74 yrs  \
# 60014001                                     0
# 60014002                                     0
# 60014003                                     1
# 60014004                                     0
# 60014005                                     0
#
#          P0120308 Other Race Females 75-79 yrs  \
# 60014001                                     0
# 60014002                                     0
# 60014003                                     2
# 60014004                                     0
# 60014005                                     0
#
#          P0120309 Other Race Females 80-84 yrs  \
# 60014001                                     0
# 60014002                                     2
# 60014003                                     0
# 60014004                                     2
# 60014005                                     0
#
#          P0120310 Other Race Females 85+ yrs
# 60014001                                   0
# 60014002                                   0
# 60014003                                   0
# 60014004                                   0
# 60014005                                   0
#
# [5 rows x 310 columns]

# %%
vars2000 = ["P012001","P012002","P012003","P012004","P012005","P012006","P012007","P012008","P012009","P012010","P012011","P012012","P012013","P012014","P012015","P012016","P012017","P012018","P012019","P012020","P012021","P012022","P012023","P012024","P012025","P012026","P012027","P012028","P012029","P012030","P012031","P012032","P012033","P012034","P012035","P012036","P012037","P012038","P012039","P012040","P012041","P012042","P012043","P012044","P012045","P012046","P012047","P012048","P012049"]

sexage2000 = census_api_pull(vars2000, 2000, "sf1", "tract")

sexage2000.head()
# Out:
# writing data to sf1_2000_tract.csv
#          P012001 SEX BY AGE:Total Male'&'Female P012002 SEX BY AGE:Total Male  \
# 61400100                                   2498                          1261
# 61400200                                   1910                           949
# 61400300                                   4878                          2342
# 61400400                                   3659                          1729
# 61400500                                   3410                          1577
#
#          P012003 SEX BY AGE:Male:'<'5 P012004 SEX BY AGE:Male:5 to 9  \
# 61400100                           55                             42
# 61400200                           49                             26
# 61400300                          134                             96
# 61400400                           86                             71
# 61400500                           72                             75
#
#          P012005 SEX BY AGE:Male:10 to 14 P012006 SEX BY AGE:Male:15 to 17  \
# 61400100                               32                               25
# 61400200                               36                               18
# 61400300                               66                               46
# 61400400                               60                               32
# 61400500                               64                               44
#
#          P012007 SEX BY AGE:Male:18'&'19 P012008 SEX BY AGE:Male:20  \
# 61400100                              13                          6
# 61400200                              14                          8
# 61400300                              32                         18
# 61400400                              29                         11
# 61400500                              30                         23
#
#          P012009 SEX BY AGE:Male:21 P012010 SEX BY AGE:Male:22 to 24  \
# 61400100                          6                               13
# 61400200                          3                               41
# 61400300                         24                               89
# 61400400                         11                               84
# 61400500                         32                               99
#
#                        ...                P012040 SEX BY AGE:Female:50 to 54  \
# 61400100               ...                                               156
# 61400200               ...                                               100
# 61400300               ...                                               211
# 61400400               ...                                               145
# 61400500               ...                                               115
#
#          P012041 SEX BY AGE:Female:55 to 59 P012042 SEX BY AGE:Female:60'&'61  \
# 61400100                                105                                36
# 61400200                                 84                                18
# 61400300                                123                                26
# 61400400                                 86                                18
# 61400500                                 68                                22
#
#          P012043 SEX BY AGE:Female:62 to 64 P012044 SEX BY AGE:Female:65'&'66  \
# 61400100                                 46                                22
# 61400200                                 16                                14
# 61400300                                 31                                25
# 61400400                                 36                                20
# 61400500                                 25                                20
#
#          P012045 SEX BY AGE:Female:67 to 69  \
# 61400100                                 36
# 61400200                                 11
# 61400300                                 31
# 61400400                                 26
# 61400500                                 16
#
#          P012046 SEX BY AGE:Female:70 to 74  \
# 61400100                                 61
# 61400200                                 21
# 61400300                                 63
# 61400400                                 46
# 61400500                                 46
#
#          P012047 SEX BY AGE:Female:75 to 79  \
# 61400100                                 43
# 61400200                                 22
# 61400300                                 72
# 61400400                                 35
# 61400500                                 62
#
#          P012048 SEX BY AGE:Female:80 to 84  \
# 61400100                                 30
# 61400200                                 21
# 61400300                                 58
# 61400400                                 35
# 61400500                                 45
#
#          P012049 SEX BY AGE:Female:85 yrs'&'over
# 61400100                                      22
# 61400200                                      23
# 61400300                                      49
# 61400400                                      30
# 61400500                                      39
#
# [5 rows x 49 columns]

# %%
vars2010 = ["P0120001","P0120002","P0120003","P0120004","P0120005","P0120006","P0120007","P0120008","P0120009","P0120010","P0120011","P0120012","P0120013","P0120014","P0120015","P0120016","P0120017","P0120018","P0120019","P0120020","P0120021","P0120022","P0120023","P0120024","P0120025","P0120026","P0120027","P0120028","P0120029","P0120030","P0120031","P0120032","P0120033","P0120034","P0120035","P0120036","P0120037","P0120038","P0120039","P0120040","P0120041","P0120042","P0120043","P0120044","P0120045","P0120046","P0120047","P0120048","P0120049"]

sexage2010 = census_api_pull(vars2010, 2010, "sf1", "tract")

sexage2010.head()
# Out:
# writing data to sf1_2010_tract.csv
#             P0120001 Total population P0120002 Male:  \
# 06001400100                      2937           1461
# 06001400200                      1974            971
# 06001400300                      4865           2228
# 06001400400                      3703           1711
# 06001400500                      3517           1677
#
#             P0120003 Male: !! Under 5 years P0120004 Male: !! 5 to 9 years  \
# 06001400100                              76                             52
# 06001400200                              74                             47
# 06001400300                             172                            102
# 06001400400                             137                             80
# 06001400500                              89                             64
#
#             P0120005 Male: !! 10 to 14 years P0120006 Male: !! 15 to 17 years  \
# 06001400100                               45                               27
# 06001400200                               34                               17
# 06001400300                               65                               48
# 06001400400                               45                               29
# 06001400500                               41                               22
#
#             P0120007 Male: !! 18 and 19 years P0120008 Male: !! 20 years  \
# 06001400100                                13                          5
# 06001400200                                 5                          6
# 06001400300                                35                          4
# 06001400400                                17                         15
# 06001400500                                20                         11
#
#             P0120009 Male: !! 21 years P0120010 Male: !! 22 to 24 years  \
# 06001400100                         13                               34
# 06001400200                          4                               27
# 06001400300                          6                               68
# 06001400400                         13                               74
# 06001400500                         23                              109
#
#                           ...                 \
# 06001400100               ...
# 06001400200               ...
# 06001400300               ...
# 06001400400               ...
# 06001400500               ...
#
#             P0120040 Female: !! 50 to 54 years  \
# 06001400100                                137
# 06001400200                                 58
# 06001400300                                180
# 06001400400                                108
# 06001400500                                 95
#
#             P0120041 Female: !! 55 to 59 years  \
# 06001400100                                156
# 06001400200                                 59
# 06001400300                                181
# 06001400400                                111
# 06001400500                                 94
#
#             P0120042 Female: !! 60 and 61 years  \
# 06001400100                                  77
# 06001400200                                  37
# 06001400300                                  74
# 06001400400                                  44
# 06001400500                                  47
#
#             P0120043 Female: !! 62 to 64 years  \
# 06001400100                                105
# 06001400200                                 55
# 06001400300                                 92
# 06001400400                                 83
# 06001400500                                 48
#
#             P0120044 Female: !! 65 and 66 years  \
# 06001400100                                  43
# 06001400200                                  39
# 06001400300                                  49
# 06001400400                                  34
# 06001400500                                  31
#
#             P0120045 Female: !! 67 to 69 years  \
# 06001400100                                 74
# 06001400200                                 39
# 06001400300                                 59
# 06001400400                                 37
# 06001400500                                 30
#
#             P0120046 Female: !! 70 to 74 years  \
# 06001400100                                 70
# 06001400200                                 39
# 06001400300                                 50
# 06001400400                                 43
# 06001400500                                 33
#
#             P0120047 Female: !! 75 to 79 years  \
# 06001400100                                 52
# 06001400200                                 22
# 06001400300                                 42
# 06001400400                                 30
# 06001400500                                 21
#
#             P0120048 Female: !! 80 to 84 years  \
# 06001400100                                 46
# 06001400200                                 15
# 06001400300                                 37
# 06001400400                                 31
# 06001400500                                 29
#
#             P0120049 Female: !! 85 years and over
# 06001400100                                    31
# 06001400200                                    15
# 06001400300                                    50
# 06001400400                                    30
# 06001400500                                    44
#
# [5 rows x 49 columns]
